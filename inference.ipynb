# %%
import os
import json
import torch
import argparse
import time

from models.model import SentenceVAE
from utils import to_var, idx2word, interpolate

def main(args):
    with open(args.data_dir+'/vocab.json', 'r') as file:
        vocab = json.load(file)

    w2i, i2w = vocab['w2i'], vocab['i2w']

    model = SentenceVAE(
        vocab_size=len(w2i),
        sos_idx=w2i['<sos>'],
        eos_idx=w2i['<eos>'],
        pad_idx=w2i['<pad>'],
        unk_idx=w2i['<unk>'],
        max_sequence_length=args.max_sequence_length,
        embedding_size=args.embedding_size,
        rnn_type=args.rnn_type,
        hidden_size=args.hidden_size,
        word_dropout=args.word_dropout,
        embedding_dropout=args.embedding_dropout,
        latent_size=args.latent_size,
        num_layers=args.num_layers,
        bidirectional=args.bidirectional
        )

    if not os.path.exists(args.load_checkpoint):
        raise FileNotFoundError(args.load_checkpoint)

    model.load_state_dict(torch.load(args.load_checkpoint))
    print("Model loaded from %s" % args.load_checkpoint)

    if torch.cuda.is_available():
        model = model.cuda()
    
    model.eval()

    samples, z = model.inference(n=args.num_samples)
    print('----------SAMPLES----------')
    print(*idx2word(samples, i2w=i2w, pad_idx=w2i['<pad>']), sep='\n')

    z1 = torch.randn([args.latent_size]).numpy()
    z2 = torch.randn([args.latent_size]).numpy()
    z = to_var(torch.from_numpy(interpolate(start=z1, end=z2, steps=8)).float())
    samples, _ = model.inference(z=z)
    print('-------INTERPOLATION-------')
    print(*idx2word(samples, i2w=i2w, pad_idx=w2i['<pad>']), sep='\n')
    
    ts = time.strftime('%Y-%b-%d-%H:%M:%S', time.gmtime())
    with open(os.path.join(args.data_dir,'results',ts+'_generate_'+str(args.num_samples)+'.txt'),'w') as rf:
        for sp in idx2word(samples, i2w=i2w, pad_idx=w2i['<pad>']):
            rf.write(sp+'\n')
    rf.close()

# %%
class Bunch(dict):
    def __init__(self, *args, **kwds):
        super(Bunch, self).__init__(*args, **kwds)
        self.__dict__ = self
inference_cfg = Bunch(
    
    
    load_checkpoint = 'checkpoints/2023-May-05-12:53:31/E353.pytorch',    #The path to the directory where PTB data is stored, and auxiliary data files will be stored.
    num_samples = 100,         #生成的新数据量
    
    data_dir = './data',
    max_sequence_length = 150, #Specifies the cut off of long sentences.
    embedding_size = 256,
    rnn_type = 'gru', #rnn_type Either 'rnn' or 'gru'.
    hidden_size = 256, #hidden_size
    word_dropout = 0, #word_dropout Word dropout applied to the input of the Decoder which means words will be replaced by <unk> with a probability of word_dropout.
    embedding_dropout = 0.3, #embedding_dropout Word embedding dropout applied to the input of the Decoder.

    latent_size = 64, #latent_size
    num_layers = 1, #num_layers
    bidirectional = False, #bidirectional
)

# %%
main(inference_cfg)
# Out:
# Model loaded from checkpoints/2023-May-05-12:53:31/E353.pytorch
# ----------SAMPLES----------
# G Q Q Q Q N Y Q Q Q P Q G Y G Q Q N Q Q Y P G Q Q G Y G Q Q N Y G Q Q N Q Q Y P G Q Q G Y G Q Q N Y G Q Q N Q Q Y P G Q Q G Y G Q Q N Y G Q Q N Q Q Y P G Q Q G Y G Q Q N Y G Q Q N Q Q Y P G Q Q G Y G Q Q N Y G Q Q N Q Q Y P G Q Q G Y G Q Q N Y G Q Q N Q Q Y P G Q Q G Y G Q Q N Y G Q Q N Q Q Y P G Q
# M K K K K K K E Y <eos>
# R G D Y S R G W M D K <eos>
# M N D K P V <eos>
# M A K K K K K K K K <eos>
# P T G V P S G T G S L F G S F N S T P V G T S L A V <eos>
# M Q A V G I N T P A E <eos>
# M V A P G V I G <eos>
# Y T P G V T G S L <eos>
# M D V L K <eos>
# M G L A I <eos>
# M K P H <eos>
# R P G Y G I G V P A G V <eos>
# M K G F N V T P <eos>
# R G D Y Q Q P Q Q G Y G Q Q N Q Y P G Q Q G Y G Q Q N Y G Q Q N Q Q N Y G Q Q N Y G Q P Q Q G Y G Q Q N Y G Q Q N Q Q Y P G Q Q G Y G Q Q N Y G Q Q N Q Q Y P G Q Q G Y G Q Q N Y G Q Q N Q Q Y P G Q Q G Y G Q Q N Y G Q Q N Q Q Y P G Q Q G Y G Q Q N Y G Q Q N Q Q Y P G Q Q G Y G Q Q N Y G Q Q N Q Q Y
# Y G I G T V P E <eos>
# A V P G V A P V G V A P V G V A P V G V A P V G V A P V G V A P V G V A P V G V A P V G V A P V G V A P V G V A P V G V A P V G V A P V G V A P V G V A P V G V A P V G V A P V G V A P V G V A P V G V A P V G V A P V G V A P V G V A P V G V A P V G V A P V G V A P V G V A P V G V A P V G V A P V G V
# M D V I <eos>
# Q Q P Y Q G Q Q Q N Y G Q Q N Q Q N Y G Q Q N Q Q N Y G Q Q N Q Q N Y G Q Q N Q Q N Y G Q Q N Q Q N Y G Q Q N Q Q N Y G Q Q N Y G Q Q N Q Q N Y G Q Q N Q Q N Y G Q Q N Y G Q Q N Q Q N Y G Q Q N Y G Q Q N Q Q N Y G Q Q N Y G Q Q N Q Q N Y G Q Q N Y G Q Q N Q Q N Y G Q Q N Y G Q Q N Q Q N Y G Q Q N Y
# T D V K <eos>
# M D K V P <eos>
# M D K L V <eos>
# K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K E Y G <eos>
# V A P V G V A P V G V A P V G V A P V G V A P V G V A P V G V A P V G V A P V G V A P V G V A P V G V A P V G V A P V G V A P V G V A P V G V A P V G <eos>
# V P G T A V G L <eos>
# M D K A K V <eos>
# G Y P G V G V A P G V G V A P V G V A P V G V A P V G V A P V G V A P V G V A P V G V A P V G V A P V G V A P V G V A P V G V A P V G <eos>
# D R Y N V E N <eos>
# M K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K E <eos>
# R Q L E <eos>
# M K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K E Y <eos>
# M L I N P Y <eos>
# M V P I G T L V <eos>
# M H H H H P L <eos>
# G M D K L V <eos>
# Q P Q G Y G Q M Q Q P Q Q Q P F G N Q Q P Y Q Q Q Q P E Q Q Q P E Q Q P E Q Q P E Q Q P E Q Q P E Q Q P E Q Q P E Q Q P E Q Q P E Q Q P E Q Q P E Q Q Q P Y G Q Q Q Q P Y Q Q Q Q Q P E Q Q Q P E Q Q P E Q Q P E Q Q P E Q Q P E Q Q Q P Y G Q Q Q Q P Y Q Q Q Q Q P E Q Q Q P E Q Q P E Q Q P E Q Q P E Q
# R G D Y N Q G Q P Y G Q Q Q N Y G Q Q N Q Q N Y G Q Q N Q Q N Y G Q Q N Q Q N Y G Q Q N Q Q Y P G Q Q Q Y G Q Q N Q Q N Y G Q Q N Q Q N Y G Q Q N Q Q N Y G Q Q N Q Q N Y G Q Q N Q Q N Y G Q Q N Y G Q Q N Q Q N Y G Q Q N Y G Q Q N Q Q N Y G Q Q N Y G Q Q N Q Q N Y G Q Q N Y G Q Q N Q Q N Y G Q Q N Y
# S D Y V T L <eos>
# V A P G V A G S L E <eos>
# P Y G V E I <eos>
# F E K K K K K K E <eos>
# D Y Q G Q Q L Y <eos>
# V D K K K K K K K K K E <eos>
# G N N R G D Y P G V G L <eos>
# V R I D Y <eos>
# R G D Y P G Q Q G Y G Q N Q N Y G Q P Q Q G Y G Q N Q Q N Y G Q P Q Q G Y G Q P Q Q G Y G Q Q N Y G Q P Q Q G Y G Q P Q Q G Y G Q Q N Y G Q P Q Q G Y G Q P Q Q G Y G Q Q N Y G Q P Q Q G Y G Q P Q Q G Y G Q Q N Y G Q P Q Q G Y G Q P Q Q G Y G Q Q N Y G Q P Q Q G Y G Q P Q Q G Y G Q Q N Y G Q P Q Q G
# T A P V G T Q Q Q Y P G Q Q Q Y G Q Q N Q Q P Y Q G Q Q Q N Y G Q Q N Q Q N Y G Q Q N Q Q N Y G Q Q N Q Q N Y G Q Q N Q Q N Y G Q Q N Q Q N Y G Q Q N Q Q N Y G Q Q N Y G Q Q N Q Q N Y G Q Q N Q Q N Y G Q Q N Y G Q Q N Q Q N Y G Q Q N Y G Q Q N Q Q N Y G Q Q N Y G Q Q N Q Q N Y G Q Q N Y G Q Q N Q Q
# E R E L I N K V <eos>
# M N K V E D Y <eos>
# M K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K
# G Y G Q M Q Q P Q Q Q A L V G L <eos>
# V P H G H L <eos>
# S Y G L A V P G T L <eos>
# Y G I N V P G T G V <eos>
# M K V P L G <eos>
# Y G I N T P V G <eos>
# G Q Q N Q Y P Q G Q Q Q N Y G Q Q N Q Q N Y G Q Q N Q Q N Y G Q Q N Q Q N Y G Q Q N Q Q N Y G Q Q N Q Q N Y G Q Q N Q Q N Y G Q Q N Q Q N Y G Q Q N Q Q N Y G Q Q N Q Q N Y G Q Q N Y G Q Q N Q Q N Y G Q Q N Y G Q Q N Q Q N Y G Q Q N Y G Q Q N Q Q N Y G Q Q N Y G Q Q N Q Q N Y G Q Q N Y G Q Q N Q Q N
# D S T P A V K <eos>
# M K V K <eos>
# M G V M D K P Y <eos>
# G G Y G A P V G V A P G V G L <eos>
# F G T P V A G S L F G S L V P A G V <eos>
# S T P S K G S G F M K K K K K K K E Y G <eos>
# R Q Q K E P <eos>
# G H S M D V I P T G <eos>
# V T P A G V L K E V N V <eos>
# S D Y S R G W G M <eos>
# D W G V P L G K T G L V P Y G C <eos>
# V A P G V A G V A P V G T V A P T G V <eos>
# M K S K P K <eos>
# M D R L I <eos>
# Q Q Q Y P G W G M K I N <eos>
# S D T S L V L <eos>
# G R G D S Y N G V P G V <eos>
# Y G I N T <eos>
# <sos> K K K K K E Y G <eos>
# G V M T P Q L A <eos>
# M K K K K V P T G <eos>
# M D L V K P Y <eos>
# S L G S N Q P A G S Y G S N A S G Y G I G P A V G <eos>
# K K K K E <eos>
# <sos> M K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K E <eos>
# G W G M V P G Y G V M <eos>
# K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K E Y <eos>
# R G D Y Q P Q G Q Y G Q Q N Q N Y G Q Q N Q Q N Y G Q Q N Q Q N Y G Q Q N Q Q N Y G Q Q N Q Q N Y G Q Q N Y G Q Q N Q Q N Y G Q Q N Y G Q Q N Q Q N Y G Q Q N Y G Q Q N Q Q N Y G Q Q N Y G Q Q N Q Q N Y G Q Q N Y G Q Q N Q Q N Y G Q Q N Y G Q Q N Q Q N Y G Q Q N Y G Q Q N Q Q N Y G Q Q N Y G Q Q N Q
# D Y Q Q Q Q Q P Q G Y G Q Q N Q Y P G Q Q G Y G Q Q N Y G Q Q N Q Q Y P G Q Q G Y G Q Q N Y G Q Q N Q Q Y P G Q Q G Y G Q Q N Y G Q Q N Q Q Y P G Q Q G Y G Q Q N Y G Q Q N Q Q Y P G Q Q G Y G Q Q N Y G Q Q N Q Q Y P G Q Q G Y G Q Q N Y G Q Q N Q Q Y P G Q Q G Y G Q Q N Y G Q Q N Q Q Y P G Q Q G Y G
# M K V G I <eos>
# G N F G S M D K K K K K K K K K K K K K K K K K K K K E Y <eos>
# G H P G V A G V P A G V <eos>
# Y G N Q P Q G Y G Q Q N Y G Q P Q Q G Y G Q P Q Q G Y G Q Q N Y G Q P Q Q G Y G Q P Q Q G Y G Q Q N Y G Q P Q Q G Y G Q P Q Q G Y G Q Q N Y G Q P Q Q G Y G Q P Q Q G Y G Q Q N Y G Q P Q Q G Y G Q P Q Q G Y G Q Q N Y G Q P Q Q G Y G Q P Q Q G Y G Q Q N Y G Q P Q Q G Y G Q P Q Q G Y G Q Q N Y G Q P Q
# H H H P H H H H H H H H H H H H H H H H H H H H H H H H H H H P <eos>
# S R G D S Y G N Q G F N G F G M D K <eos>
# Q Q Q E N Y G I N P <eos>
# G K T H H H H H H <eos>
# M V P T G V <eos>
# M K K A K <eos>
# M I P R E I V K <eos>
# R G D S Y G N Q G F N G F G S M D K K <eos>
# G M <eos>
# G F N G F G N F G S N R G D S Y <eos>
# -------INTERPOLATION-------
# V K K E Y <eos>
# V K E N V <eos>
# K V E N <eos>
# K V E N <eos>
# K V E <eos>
# K V E <eos>
# R G N Y <eos>
# R G N F G S N V P T G S <eos>
# R G N F G S N R G D S Y P G V G V A P G V <eos>
# R G F N F G S D S Y G V P <eos>
